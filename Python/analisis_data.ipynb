# %% [markdown]
# ### Bibliotecas

# %%
import pandas as pd ## para la manipulación y el análisis de datos
import numpy as np ## realizar cálculos lógicos y matemáticos sobre cuadros y matrices
import matplotlib as plt ##creación de gráficos en dos dimensiones
import matplotlib.pyplot as plt ##añadir elementos tales como líneas, imágenes o textos a los ejes de un gráfico

# %% [markdown]
# ### Importar data

# %%
launches = pd.read_csv("../Datos/mission_launches.csv")
launches.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 Organisation  \
# 0             0           0       SpaceX
# 1             1           1         CASC
# 2             2           2       SpaceX
# 3             3           3    Roscosmos
# 4             4           4          ULA
#
#                                             Location  \
# 0         LC-39A, Kennedy Space Center, Florida, USA
# 1  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2                      Pad A, Boca Chica, Texas, USA
# 3       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4           SLC-41, Cape Canaveral AFS, Florida, USA
#
#                          Date                                        Detail  \
# 0  Fri Aug 07, 2020 05:12 UTC  Falcon 9 Block 5 | Starlink V1 L9 & BlackSky
# 1  Thu Aug 06, 2020 04:01 UTC           Long March 2D | Gaofen-9 04 & Q-SAT
# 2  Tue Aug 04, 2020 23:57 UTC            Starship Prototype | 150 Meter Hop
# 3  Thu Jul 30, 2020 21:25 UTC  Proton-M/Briz-M | Ekspress-80 & Ekspress-103
# ...

# %% [markdown]
# ### Información Data

# %%
launches
# Out:
#       Unnamed: 0.1  Unnamed: 0 Organisation  \
# 0                0           0       SpaceX
# 1                1           1         CASC
# 2                2           2       SpaceX
# 3                3           3    Roscosmos
# 4                4           4          ULA
# ...            ...         ...          ...
# 4319          4319        4319      US Navy
# 4320          4320        4320         AMBA
# 4321          4321        4321      US Navy
# 4322          4322        4322    RVSN USSR
# 4323          4323        4323    RVSN USSR
#
#                                                Location  \
# 0            LC-39A, Kennedy Space Center, Florida, USA
# 1     Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2                         Pad A, Boca Chica, Texas, USA
# 3          Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4              SLC-41, Cape Canaveral AFS, Florida, USA
# ...                                                 ...
# ...

# %% [markdown]
# ### Renombramos columna

# %%
launches.rename(columns={'Organisation': 'Organization'}, inplace=True) ###Cambiar nombre
launches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4324 entries, 0 to 4323
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0.1    4324 non-null   int64
#  1   Unnamed: 0      4324 non-null   int64
#  2   Organization    4324 non-null   object
#  3   Location        4324 non-null   object
#  4   Date            4324 non-null   object
#  5   Detail          4324 non-null   object
#  6   Rocket_Status   4324 non-null   object
#  7   Price           964 non-null    object
#  8   Mission_Status  4324 non-null   object
# dtypes: int64(2), object(7)
# memory usage: 304.2+ KB

# %% [markdown]
# ### Eliminamos cuyas ya no se usan

# %%
launches_renombrado = launches.drop(['Unnamed: 0.1', 'Unnamed: 0'], axis=1)

# %%
launches_renombrado.drop_duplicates()
# Out:
#      Organization                                           Location  \
# 0          SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1            CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2          SpaceX                      Pad A, Boca Chica, Texas, USA
# 3       Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4             ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...           ...                                                ...
# 4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                             Date  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 2     Tue Aug 04, 2020 23:57 UTC
# ...

# %% [markdown]
# ### Analisis al campo price

# %%
launches_renombrado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4324 entries, 0 to 4323
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Organization    4324 non-null   object
#  1   Location        4324 non-null   object
#  2   Date            4324 non-null   object
#  3   Detail          4324 non-null   object
#  4   Rocket_Status   4324 non-null   object
#  5   Price           964 non-null    object
#  6   Mission_Status  4324 non-null   object
# dtypes: object(7)
# memory usage: 236.6+ KB

# %%
launches_renombrado['Price'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 4324 entries, 0 to 4323
# Series name: Price
# Non-Null Count  Dtype
# --------------  -----
# 964 non-null    object
# dtypes: object(1)
# memory usage: 33.9+ KB

# %% [markdown]
# ### Ejecutamos la media para los valores nulos del precio para no eliminar información

# %%
launches_no_nulos = launches_renombrado
# Convertir la columna 'Price' a tipo numérico
launches_no_nulos['Price'] = pd.to_numeric(launches_no_nulos['Price'], errors='coerce')

# Calcular la media de la columna 'Price' (excluyendo los valores nulos)
precio_medio = launches_no_nulos['Price'].mean()

# Llenar los valores nulos en la columna 'Price' con la media
launches_no_nulos['Price'].fillna(precio_medio, inplace=True)
# Out:
# C:\Users\Sernita\AppData\Local\Temp\ipykernel_14716\1375453164.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   launches_no_nulos['Price'].fillna(precio_medio, inplace=True)

# %%
launches_no_nulos
# Out:
#      Organization                                           Location  \
# 0          SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1            CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2          SpaceX                      Pad A, Boca Chica, Texas, USA
# 3       Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4             ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...           ...                                                ...
# 4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                             Date  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 2     Tue Aug 04, 2020 23:57 UTC
# ...

# %%
launches_no_nulos
# Out:
#      Organization                                           Location  \
# 0          SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1            CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2          SpaceX                      Pad A, Boca Chica, Texas, USA
# 3       Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4             ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...           ...                                                ...
# 4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                             Date  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 2     Tue Aug 04, 2020 23:57 UTC
# ...

# %%
import pandas as pd

# Convertir la columna 'Date' a formato datetime
try:
    launches_no_nulos['Date'] = pd.to_datetime(launches_no_nulos['Date'], errors='raise', format='%d %b %Y')
    launches_no_nulos['formatted_date'] = launches_no_nulos['Date'].dt.strftime('%a %b %d')
except ValueError as e:
    print("Error al convertir la fecha:", e)

launches_no_nulos
# Out:
# Error al convertir la fecha: time data "Fri Aug 07, 2020 05:12 UTC" doesn't match format "%d %b %Y", at position 0. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.
#      Organization                                           Location  \
# 0          SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1            CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2          SpaceX                      Pad A, Boca Chica, Texas, USA
# 3       Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4             ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...           ...                                                ...
# ...

# %%
# Reemplazar las comas por un string vacío y luego convertir a flotante
launches_no_nulos['Price'] = pd.to_numeric(launches_no_nulos['Price'], errors='coerce')
launches_no_nulos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4324 entries, 0 to 4323
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Organization    4324 non-null   object
#  1   Location        4324 non-null   object
#  2   Date            4324 non-null   object
#  3   Detail          4324 non-null   object
#  4   Rocket_Status   4324 non-null   object
#  5   Price           4324 non-null   float64
#  6   Mission_Status  4324 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 236.6+ KB

# %%
launches_no_nulos
# Out:
#      Organization                                           Location  \
# 0          SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1            CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2          SpaceX                      Pad A, Boca Chica, Texas, USA
# 3       Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4             ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...           ...                                                ...
# 4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                             Date  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 2     Tue Aug 04, 2020 23:57 UTC
# ...

# %% [markdown]
# # Preguntas

# %% [markdown]
# ### Organización de misiones espaciales
#
# - **¿Qué organización lanzó más misiones espaciales en un año determinado?**
#   - Proporciona información sobre qué agencia espacial o compañía ha lanzado el mayor número de misiones en un año específico.

# %%
###import pandas as pd
#from datetime import datetime

# Función para convertir la fecha a un formato específico
#def convertir_fecha(fecha_str):
    # Eliminar la parte de la hora UTC si está presente
 ### for formato in formatos:
    #####raise ValueError("El formato de la fecha no coincide con ninguno de los formatos esperados.")



# Convertir la columna 'date' a formato datetime con manejo de errores
#try:
 #   launches_no_nulos['Date'] = launches_no_nulos['Date'].apply(convertir_fecha)
#except ValueError as e:
 #   print("Error al convertir la fecha:", e)


launches_no_nulos
# Out:
#      Organization                                           Location  \
# 0          SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1            CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2          SpaceX                      Pad A, Boca Chica, Texas, USA
# 3       Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4             ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...           ...                                                ...
# 4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                             Date  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 2     Tue Aug 04, 2020 23:57 UTC
# ...

# %%
launches_no_nulos
# Out:
#      Organization                                           Location  \
# 0          SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1            CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2          SpaceX                      Pad A, Boca Chica, Texas, USA
# 3       Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4             ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...           ...                                                ...
# 4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                             Date  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 2     Tue Aug 04, 2020 23:57 UTC
# ...

# %% [markdown]
# ## Agrupar por fecha

# %%
# Convertir la columna 'Date' a formato datetime si no está en ese formato
launches_no_nulos['Date'] = pd.to_datetime(launches_no_nulos['Date'], errors='coerce')

# Filtrar las fechas del año 2000
launches_no_nulos_2000 = launches_no_nulos[launches_no_nulos['Date'].dt.year == 2018]

# Mostrar el DataFrame filtrado
launches_no_nulos_2000
# Out:
#     Organization                                           Location  \
# 172         CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 173    Roscosmos              Site 1S, Vostochny Cosmodrome, Russia
# 174         CASC       LC-3, Xichang Satellite Launch Center, China
# 175       SpaceX           SLC-40, Cape Canaveral AFS, Florida, USA
# 176         CASC    Site 95, Jiuquan Satellite Launch Center, China
# ..           ...                                                ...
# 284          ULA             SLC-6, Vandenberg AFB, California, USA
# 285         ISRO  First Launch Pad, Satish Dhawan Space Centre, ...
# 286         CASC       LC-2, Xichang Satellite Launch Center, China
# 287         CASC       LC-9, Taiyuan Satellite Launch Center, China
# 288       SpaceX           SLC-40, Cape Canaveral AFS, Florida, USA
#
#                          Date  \
# 172 2018-12-29 08:02:00+00:00
# 173 2018-12-27 02:07:00+00:00
# 174 2018-12-24 16:53:00+00:00
# ...

# %% [markdown]
# ### ¿Qué organización lanzó más misiones espaciales en un año determinado?
#   año 2018

# %%
# Agrupar por título y calcular el promedio y la mediana del salario para cada título
df_grouped = launches_no_nulos_2000.groupby('Organization')['Date'].agg(['count']).reset_index()

# Renombrar las columnas para mayor claridad
df_grouped.columns = ['Organization',  'Organization_count']

# Mostrar el DataFrame resultante
df_grouped
# Out:
#    Organization  Organization_count
# 0   Arianespace                  11
# 1   Blue Origin                   2
# 2          CASC                  37
# 3      Eurockot                   1
# 4        ExPace                   1
# 5          Exos                   1
# 6          ISRO                   7
# 7          JAXA                   2
# 8     Landspace                   1
# 9           MHI                   4
# 10     Northrop                   2
# 11   Rocket Lab                   3
# 12    Roscosmos                  11
# 13       SpaceX                  21
# 14          ULA                   8
# 15       VKS RF                   5

# %%
# Ordenar el DataFrame por la columna 'Organization_count' de manera descendente
df_grouped_sorted = df_grouped.sort_values(by='Organization_count', ascending=False)

# Mostrar el DataFrame ordenado
print("Títulos ordenados de mayor a menor por número de lanzamientos:")
print(df_grouped_sorted)
# Out:
# Títulos ordenados de mayor a menor por número de lanzamientos:
#    Organization  Organization_count
# 2          CASC                  37
# 13       SpaceX                  21
# 0   Arianespace                  11
# 12    Roscosmos                  11
# 14          ULA                   8
# 6          ISRO                   7
# 15       VKS RF                   5
# 9           MHI                   4
# 11   Rocket Lab                   3
# 1   Blue Origin                   2
# 7          JAXA                   2
# 10     Northrop                   2
# 3      Eurockot                   1
# 4        ExPace                   1
# 5          Exos                   1
# 8     Landspace                   1

# %%
# Obtener el título con el mayor número de lanzamientos
titulo_max_lanzamientos = df_grouped.loc[df_grouped['Organization_count'].idxmax(), 'Organization']

print("Título con el mayor número de lanzamientos:", titulo_max_lanzamientos)
# Out:
# Título con el mayor número de lanzamientos: CASC

# %% [markdown]
# ### ¿Cuántos lanzamientos se realizaron por año?

# %%
launches_no_nulos
# Out:
#      Organization                                           Location  \
# 0          SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1            CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2          SpaceX                      Pad A, Boca Chica, Texas, USA
# 3       Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4             ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...           ...                                                ...
# 4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                           Date                                        Detail  \
# ...

# %%
# Extraer el año de la fecha y crear una nueva columna 'Year'
launches_no_nulos['Year'] = launches_no_nulos['Date'].dt.year

# Agrupar por año y contar el número de lanzamientos en cada año
lanzamientos_por_año = launches_no_nulos.groupby('Year').size()

# Mostrar los lanzamientos por año
lanzamientos_por_año
# Out:
# Year
# 1957.0      3
# 1958.0     22
# 1959.0     20
# 1960.0     38
# 1961.0     52
#          ...
# 2016.0     88
# 2017.0     90
# 2018.0    117
# 2019.0    107
# 2020.0     63
# Length: 64, dtype: int64

# %% [markdown]
# ### Gráfica

# %%
# Graficar los lanzamientos por año con un tamaño de gráfico más grande
plt.figure(figsize=(12, 8))
lanzamientos_por_año.plot(kind='bar', color='skyblue')
plt.title('Lanzamientos por año')
plt.xlabel('Año')
plt.ylabel('Número de lanzamientos')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Costo a raiz del tiempo

# %%
# Calcular el costo promedio de las misiones para cada año
costo_promedio_por_año = launches_no_nulos.groupby(launches_no_nulos['Date'].dt.year)['Price'].mean()

# Graficar el costo promedio de las misiones a lo largo del tiempo
plt.figure(figsize=(12, 6))
costo_promedio_por_año.plot(marker='o', linestyle='-', color='b')
plt.title('Costo promedio de las misiones espaciales por año (1954-2020)')
plt.xlabel('Año')
plt.ylabel('Costo promedio de la misión')
plt.grid(True)
plt.xticks(range(1954, 2021), rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### ¿Qué meses son los más populares para los lanzamientos?

# %%
# Extraer el mes de la fecha y crear una nueva columna 'Month'
launches_for_month = launches_no_nulos
launches_for_month['Month'] = launches_no_nulos['Date'].dt.month

# Contar el número de lanzamientos en cada mes
lanzamientos_por_mes = launches_for_month['Month'].value_counts()

# Encontrar los meses con el mayor número de lanzamientos
meses_populares = lanzamientos_por_mes[lanzamientos_por_mes == lanzamientos_por_mes.max()]

meses_populares
# Out:
# Month
# 12.0    430
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Ordenar los meses en orden cronológico
meses_ordenados = lanzamientos_por_mes.sort_index()

# Graficar la cantidad de lanzamientos por mes
plt.figure(figsize=(10, 6))
meses_ordenados.plot(kind='bar', color='skyblue')
plt.title('Cantidad de lanzamientos por mes')
plt.xlabel('Mes')
plt.ylabel('Cantidad de lanzamientos')
plt.xticks(range(0, 12), ['Ene', 'Feb', 'Mar', 'Abr', 'May', 'Jun', 'Jul', 'Ago', 'Sep', 'Oct', 'Nov', 'Dic'], rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### ¿Se han vuelto más seguras las misiones espaciales o las posibilidades de fracaso se han mantenido sin cambios?

# %%
# Crear un gráfico de barras apiladas para mostrar la distribución de los estados de misión a lo largo del tiempo
plt.figure(figsize=(10, 6))

# Contar el número de misiones exitosas y fallidas para cada año
success_counts = launches_no_nulos[launches_no_nulos['Mission_Status'] == 'Success'].groupby(launches_no_nulos['Date'].dt.year).size()
failure_counts = launches_no_nulos[launches_no_nulos['Mission_Status'] == 'Failure'].groupby(launches_no_nulos['Date'].dt.year).size()

# Graficar las barras apiladas
plt.bar(success_counts.index, success_counts, color='lightgreen', label='Éxito')
plt.bar(failure_counts.index, failure_counts, color='coral', label='Fracaso')

plt.title('Distribución de estados de misión a lo largo del tiempo')
plt.xlabel('Año')
plt.ylabel('Número de misiones')
plt.legend()
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Bibliotecas

# %%
import pandas as pd ## para la manipulación y el análisis de datos
import numpy as np ## realizar cálculos lógicos y matemáticos sobre cuadros y matrices
import matplotlib as plt ##creación de gráficos en dos dimensiones
import matplotlib.pyplot as plt ##añadir elementos tales como líneas, imágenes o textos a los ejes de un gráfico

# %% [markdown]
# ### Importar data

# %%
launches = pd.read_csv("../Datos/mission_launches.csv")
launches.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 Organisation  \
# 0             0           0       SpaceX
# 1             1           1         CASC
# 2             2           2       SpaceX
# 3             3           3    Roscosmos
# 4             4           4          ULA
#
#                                             Location  \
# 0         LC-39A, Kennedy Space Center, Florida, USA
# 1  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2                      Pad A, Boca Chica, Texas, USA
# 3       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4           SLC-41, Cape Canaveral AFS, Florida, USA
#
#                          Date                                        Detail  \
# 0  Fri Aug 07, 2020 05:12 UTC  Falcon 9 Block 5 | Starlink V1 L9 & BlackSky
# 1  Thu Aug 06, 2020 04:01 UTC           Long March 2D | Gaofen-9 04 & Q-SAT
# 2  Tue Aug 04, 2020 23:57 UTC            Starship Prototype | 150 Meter Hop
# 3  Thu Jul 30, 2020 21:25 UTC  Proton-M/Briz-M | Ekspress-80 & Ekspress-103
# 4  Thu Jul 30, 2020 11:50 UTC                    Atlas V 541 | Perseverance
#
#   Rocket_Status  Price Mission_Status
# 0  StatusActive   50.0        Success
# 1  StatusActive  29.75        Success
# 2  StatusActive    NaN        Success
# 3  StatusActive   65.0        Success
# 4  StatusActive  145.0        Success

# %% [markdown]
# ### Información Data

# %%
launches
# Out:
#       Unnamed: 0.1  Unnamed: 0 Organisation  \
# 0                0           0       SpaceX
# 1                1           1         CASC
# 2                2           2       SpaceX
# 3                3           3    Roscosmos
# 4                4           4          ULA
# ...            ...         ...          ...
# 4319          4319        4319      US Navy
# 4320          4320        4320         AMBA
# 4321          4321        4321      US Navy
# 4322          4322        4322    RVSN USSR
# 4323          4323        4323    RVSN USSR
#
#                                                Location  \
# 0            LC-39A, Kennedy Space Center, Florida, USA
# 1     Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2                         Pad A, Boca Chica, Texas, USA
# 3          Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4              SLC-41, Cape Canaveral AFS, Florida, USA
# ...                                                 ...
# 4319           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                             Date  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 2     Tue Aug 04, 2020 23:57 UTC
# 3     Thu Jul 30, 2020 21:25 UTC
# 4     Thu Jul 30, 2020 11:50 UTC
# ...                          ...
# 4319  Wed Feb 05, 1958 07:33 UTC
# 4320  Sat Feb 01, 1958 03:48 UTC
# 4321  Fri Dec 06, 1957 16:44 UTC
# 4322  Sun Nov 03, 1957 02:30 UTC
# 4323  Fri Oct 04, 1957 19:28 UTC
#
#                                             Detail  Rocket_Status  Price  \
# 0     Falcon 9 Block 5 | Starlink V1 L9 & BlackSky   StatusActive   50.0
# 1              Long March 2D | Gaofen-9 04 & Q-SAT   StatusActive  29.75
# 2               Starship Prototype | 150 Meter Hop   StatusActive    NaN
# 3     Proton-M/Briz-M | Ekspress-80 & Ekspress-103   StatusActive   65.0
# 4                       Atlas V 541 | Perseverance   StatusActive  145.0
# ...                                            ...            ...    ...
# 4319                     Vanguard | Vanguard TV3BU  StatusRetired    NaN
# 4320                           Juno I | Explorer 1  StatusRetired    NaN
# 4321                       Vanguard | Vanguard TV3  StatusRetired    NaN
# 4322                    Sputnik 8K71PS | Sputnik-2  StatusRetired    NaN
# 4323                    Sputnik 8K71PS | Sputnik-1  StatusRetired    NaN
#
#      Mission_Status
# 0           Success
# 1           Success
# 2           Success
# 3           Success
# 4           Success
# ...             ...
# 4319        Failure
# 4320        Success
# 4321        Failure
# 4322        Success
# 4323        Success
#
# [4324 rows x 9 columns]

# %% [markdown]
# ### Renombramos columna

# %%
launches.rename(columns={'Organisation': 'Organization'}, inplace=True) ###Cambiar nombre
launches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4324 entries, 0 to 4323
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0.1    4324 non-null   int64
#  1   Unnamed: 0      4324 non-null   int64
#  2   Organization    4324 non-null   object
#  3   Location        4324 non-null   object
#  4   Date            4324 non-null   object
#  5   Detail          4324 non-null   object
#  6   Rocket_Status   4324 non-null   object
#  7   Price           964 non-null    object
#  8   Mission_Status  4324 non-null   object
# dtypes: int64(2), object(7)
# memory usage: 304.2+ KB

# %% [markdown]
# ### Eliminamos cuyas ya no se usan

# %%
launches_renombrado = launches.drop(['Unnamed: 0.1', 'Unnamed: 0'], axis=1)

# %%
launches_renombrado.drop_duplicates()
# Out:
#      Organization                                           Location  \
# 0          SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1            CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2          SpaceX                      Pad A, Boca Chica, Texas, USA
# 3       Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4             ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...           ...                                                ...
# 4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                             Date  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 2     Tue Aug 04, 2020 23:57 UTC
# 3     Thu Jul 30, 2020 21:25 UTC
# 4     Thu Jul 30, 2020 11:50 UTC
# ...                          ...
# 4319  Wed Feb 05, 1958 07:33 UTC
# 4320  Sat Feb 01, 1958 03:48 UTC
# 4321  Fri Dec 06, 1957 16:44 UTC
# 4322  Sun Nov 03, 1957 02:30 UTC
# 4323  Fri Oct 04, 1957 19:28 UTC
#
#                                             Detail  Rocket_Status  Price  \
# 0     Falcon 9 Block 5 | Starlink V1 L9 & BlackSky   StatusActive   50.0
# 1              Long March 2D | Gaofen-9 04 & Q-SAT   StatusActive  29.75
# 2               Starship Prototype | 150 Meter Hop   StatusActive    NaN
# 3     Proton-M/Briz-M | Ekspress-80 & Ekspress-103   StatusActive   65.0
# 4                       Atlas V 541 | Perseverance   StatusActive  145.0
# ...                                            ...            ...    ...
# 4319                     Vanguard | Vanguard TV3BU  StatusRetired    NaN
# 4320                           Juno I | Explorer 1  StatusRetired    NaN
# 4321                       Vanguard | Vanguard TV3  StatusRetired    NaN
# 4322                    Sputnik 8K71PS | Sputnik-2  StatusRetired    NaN
# 4323                    Sputnik 8K71PS | Sputnik-1  StatusRetired    NaN
#
#      Mission_Status
# 0           Success
# 1           Success
# 2           Success
# 3           Success
# 4           Success
# ...             ...
# 4319        Failure
# 4320        Success
# 4321        Failure
# 4322        Success
# 4323        Success
#
# [4323 rows x 7 columns]

# %% [markdown]
# ### Analisis al campo price

# %%
launches_renombrado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4324 entries, 0 to 4323
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Organization    4324 non-null   object
#  1   Location        4324 non-null   object
#  2   Date            4324 non-null   object
#  3   Detail          4324 non-null   object
#  4   Rocket_Status   4324 non-null   object
#  5   Price           964 non-null    object
#  6   Mission_Status  4324 non-null   object
# dtypes: object(7)
# memory usage: 236.6+ KB

# %%
launches_renombrado['Price'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 4324 entries, 0 to 4323
# Series name: Price
# Non-Null Count  Dtype
# --------------  -----
# 964 non-null    object
# dtypes: object(1)
# memory usage: 33.9+ KB

# %%
launches_no_nulos = launches_renombrado.dropna()

# %%
launches_no_nulos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 964 entries, 0 to 4020
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Organization    964 non-null    object
#  1   Location        964 non-null    object
#  2   Date            964 non-null    object
#  3   Detail          964 non-null    object
#  4   Rocket_Status   964 non-null    object
#  5   Price           964 non-null    object
#  6   Mission_Status  964 non-null    object
# dtypes: object(7)
# memory usage: 60.2+ KB

# %%
launches_no_nulos
# Out:
#       Organization                                           Location  \
# 0           SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1             CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 3        Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4              ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# 5             CASC       LC-9, Taiyuan Satellite Launch Center, China
# ...            ...                                                ...
# 3855  US Air Force            SLC-4W, Vandenberg AFB, California, USA
# 3971  US Air Force           SLC-20, Cape Canaveral AFS, Florida, USA
# 3993  US Air Force           SLC-20, Cape Canaveral AFS, Florida, USA
# 4000  US Air Force           SLC-20, Cape Canaveral AFS, Florida, USA
# 4020  US Air Force           SLC-20, Cape Canaveral AFS, Florida, USA
#
#                             Date  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 3     Thu Jul 30, 2020 21:25 UTC
# 4     Thu Jul 30, 2020 11:50 UTC
# 5     Sat Jul 25, 2020 03:13 UTC
# ...                          ...
# 3855  Fri Jul 29, 1966 18:43 UTC
# 3971  Thu May 06, 1965 15:00 UTC
# 3993  Thu Feb 11, 1965 15:19 UTC
# 4000  Thu Dec 10, 1964 16:52 UTC
# 4020  Tue Sep 01, 1964 15:00 UTC
#
#                                                  Detail  Rocket_Status  Price  \
# 0          Falcon 9 Block 5 | Starlink V1 L9 & BlackSky   StatusActive   50.0
# 1                   Long March 2D | Gaofen-9 04 & Q-SAT   StatusActive  29.75
# 3          Proton-M/Briz-M | Ekspress-80 & Ekspress-103   StatusActive   65.0
# 4                            Atlas V 541 | Perseverance   StatusActive  145.0
# 5     Long March 4B | Ziyuan-3 03, Apocalypse-10 & N...   StatusActive  64.68
# ...                                                 ...            ...    ...
# 3855                                  Titan IIIB | KH-8  StatusRetired   59.0
# 3971                         Titan IIIA | LES 2 & LCS 1  StatusRetired  63.23
# 3993                                 Titan IIIA | LES 1  StatusRetired  63.23
# 4000                           Titan IIIA | Transtage 2  StatusRetired  63.23
# 4020                           Titan IIIA | Transtage 1  StatusRetired  63.23
#
#      Mission_Status
# 0           Success
# 1           Success
# 3           Success
# 4           Success
# 5           Success
# ...             ...
# 3855        Success
# 3971        Success
# 3993        Success
# 4000        Success
# 4020        Failure
#
# [964 rows x 7 columns]

# %%
import pandas as pd

# Convertir la columna 'Date' a formato datetime
try:
    launches_no_nulos['Date'] = pd.to_datetime(launches_no_nulos['Date'], errors='raise', format='%d %b %Y')
    launches_no_nulos['formatted_date'] = launches_no_nulos['Date'].dt.strftime('%a %b %d')
except ValueError as e:
    print("Error al convertir la fecha:", e)

launches_no_nulos
# Out:
# Error al convertir la fecha: time data "Fri Aug 07, 2020 05:12 UTC" doesn't match format "%d %b %Y", at position 0. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.
#       Organization                                           Location  \
# 0           SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1             CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 3        Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4              ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# 5             CASC       LC-9, Taiyuan Satellite Launch Center, China
# ...            ...                                                ...
# 3855  US Air Force            SLC-4W, Vandenberg AFB, California, USA
# 3971  US Air Force           SLC-20, Cape Canaveral AFS, Florida, USA
# 3993  US Air Force           SLC-20, Cape Canaveral AFS, Florida, USA
# 4000  US Air Force           SLC-20, Cape Canaveral AFS, Florida, USA
# 4020  US Air Force           SLC-20, Cape Canaveral AFS, Florida, USA
#
#                             Date  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 3     Thu Jul 30, 2020 21:25 UTC
# 4     Thu Jul 30, 2020 11:50 UTC
# 5     Sat Jul 25, 2020 03:13 UTC
# ...                          ...
# 3855  Fri Jul 29, 1966 18:43 UTC
# 3971  Thu May 06, 1965 15:00 UTC
# 3993  Thu Feb 11, 1965 15:19 UTC
# 4000  Thu Dec 10, 1964 16:52 UTC
# 4020  Tue Sep 01, 1964 15:00 UTC
#
#                                                  Detail  Rocket_Status  Price  \
# 0          Falcon 9 Block 5 | Starlink V1 L9 & BlackSky   StatusActive   50.0
# 1                   Long March 2D | Gaofen-9 04 & Q-SAT   StatusActive  29.75
# 3          Proton-M/Briz-M | Ekspress-80 & Ekspress-103   StatusActive   65.0
# 4                            Atlas V 541 | Perseverance   StatusActive  145.0
# 5     Long March 4B | Ziyuan-3 03, Apocalypse-10 & N...   StatusActive  64.68
# ...                                                 ...            ...    ...
# 3855                                  Titan IIIB | KH-8  StatusRetired   59.0
# 3971                         Titan IIIA | LES 2 & LCS 1  StatusRetired  63.23
# 3993                                 Titan IIIA | LES 1  StatusRetired  63.23
# 4000                           Titan IIIA | Transtage 2  StatusRetired  63.23
# 4020                           Titan IIIA | Transtage 1  StatusRetired  63.23
#
#      Mission_Status
# 0           Success
# 1           Success
# 3           Success
# 4           Success
# 5           Success
# ...             ...
# 3855        Success
# 3971        Success
# 3993        Success
# 4000        Success
# 4020        Failure
#
# [964 rows x 7 columns]

# %%
# Reemplazar las comas por un string vacío y luego convertir a flotante
launches_no_nulos['Price'] = pd.to_numeric(launches_no_nulos['Price'], errors='coerce')
launches_no_nulos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 964 entries, 0 to 4020
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Organization    964 non-null    object
#  1   Location        964 non-null    object
#  2   Date            964 non-null    object
#  3   Detail          964 non-null    object
#  4   Rocket_Status   964 non-null    object
#  5   Price           949 non-null    float64
#  6   Mission_Status  964 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 60.2+ KB
# C:\Users\Sernita\AppData\Local\Temp\ipykernel_3160\26832663.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   launches_no_nulos['Price'] = pd.to_numeric(launches_no_nulos['Price'], errors='coerce')

# %%
launches_no_nulos
# Out:
#       Organization                                           Location  \
# 0           SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1             CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 3        Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4              ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# 5             CASC       LC-9, Taiyuan Satellite Launch Center, China
# ...            ...                                                ...
# 3855  US Air Force            SLC-4W, Vandenberg AFB, California, USA
# 3971  US Air Force           SLC-20, Cape Canaveral AFS, Florida, USA
# 3993  US Air Force           SLC-20, Cape Canaveral AFS, Florida, USA
# 4000  US Air Force           SLC-20, Cape Canaveral AFS, Florida, USA
# 4020  US Air Force           SLC-20, Cape Canaveral AFS, Florida, USA
#
#                             Date  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 3     Thu Jul 30, 2020 21:25 UTC
# 4     Thu Jul 30, 2020 11:50 UTC
# 5     Sat Jul 25, 2020 03:13 UTC
# ...                          ...
# 3855  Fri Jul 29, 1966 18:43 UTC
# 3971  Thu May 06, 1965 15:00 UTC
# 3993  Thu Feb 11, 1965 15:19 UTC
# 4000  Thu Dec 10, 1964 16:52 UTC
# 4020  Tue Sep 01, 1964 15:00 UTC
#
#                                                  Detail  Rocket_Status  \
# 0          Falcon 9 Block 5 | Starlink V1 L9 & BlackSky   StatusActive
# 1                   Long March 2D | Gaofen-9 04 & Q-SAT   StatusActive
# 3          Proton-M/Briz-M | Ekspress-80 & Ekspress-103   StatusActive
# 4                            Atlas V 541 | Perseverance   StatusActive
# 5     Long March 4B | Ziyuan-3 03, Apocalypse-10 & N...   StatusActive
# ...                                                 ...            ...
# 3855                                  Titan IIIB | KH-8  StatusRetired
# 3971                         Titan IIIA | LES 2 & LCS 1  StatusRetired
# 3993                                 Titan IIIA | LES 1  StatusRetired
# 4000                           Titan IIIA | Transtage 2  StatusRetired
# 4020                           Titan IIIA | Transtage 1  StatusRetired
#
#        Price Mission_Status
# 0      50.00        Success
# 1      29.75        Success
# 3      65.00        Success
# 4     145.00        Success
# 5      64.68        Success
# ...      ...            ...
# 3855   59.00        Success
# 3971   63.23        Success
# 3993   63.23        Success
# 4000   63.23        Success
# 4020   63.23        Failure
#
# [964 rows x 7 columns]

# %% [markdown]
# # Preguntas

# %% [markdown]
# ### Organización de misiones espaciales
#
# - **¿Qué organización lanzó más misiones espaciales en un año determinado?**
#   - Proporciona información sobre qué agencia espacial o compañía ha lanzado el mayor número de misiones en un año específico.

# %%
###import pandas as pd
#from datetime import datetime

# Función para convertir la fecha a un formato específico
#def convertir_fecha(fecha_str):
    # Eliminar la parte de la hora UTC si está presente
 ### for formato in formatos:
    #####raise ValueError("El formato de la fecha no coincide con ninguno de los formatos esperados.")



# Convertir la columna 'date' a formato datetime con manejo de errores
#try:
 #   launches_no_nulos['Date'] = launches_no_nulos['Date'].apply(convertir_fecha)
#except ValueError as e:
 #   print("Error al convertir la fecha:", e)


launches_no_nulos
# Out:
#       Organization                                           Location  \
# 0           SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1             CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 3        Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4              ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# 5             CASC       LC-9, Taiyuan Satellite Launch Center, China
# ...            ...                                                ...
# 3855  US Air Force            SLC-4W, Vandenberg AFB, California, USA
# 3971  US Air Force           SLC-20, Cape Canaveral AFS, Florida, USA
# 3993  US Air Force           SLC-20, Cape Canaveral AFS, Florida, USA
# 4000  US Air Force           SLC-20, Cape Canaveral AFS, Florida, USA
# 4020  US Air Force           SLC-20, Cape Canaveral AFS, Florida, USA
#
#                             Date  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 3     Thu Jul 30, 2020 21:25 UTC
# 4     Thu Jul 30, 2020 11:50 UTC
# 5     Sat Jul 25, 2020 03:13 UTC
# ...                          ...
# 3855  Fri Jul 29, 1966 18:43 UTC
# 3971  Thu May 06, 1965 15:00 UTC
# 3993  Thu Feb 11, 1965 15:19 UTC
# 4000  Thu Dec 10, 1964 16:52 UTC
# 4020  Tue Sep 01, 1964 15:00 UTC
#
#                                                  Detail  Rocket_Status  \
# 0          Falcon 9 Block 5 | Starlink V1 L9 & BlackSky   StatusActive
# 1                   Long March 2D | Gaofen-9 04 & Q-SAT   StatusActive
# 3          Proton-M/Briz-M | Ekspress-80 & Ekspress-103   StatusActive
# 4                            Atlas V 541 | Perseverance   StatusActive
# 5     Long March 4B | Ziyuan-3 03, Apocalypse-10 & N...   StatusActive
# ...                                                 ...            ...
# 3855                                  Titan IIIB | KH-8  StatusRetired
# 3971                         Titan IIIA | LES 2 & LCS 1  StatusRetired
# 3993                                 Titan IIIA | LES 1  StatusRetired
# 4000                           Titan IIIA | Transtage 2  StatusRetired
# 4020                           Titan IIIA | Transtage 1  StatusRetired
#
#        Price Mission_Status
# 0      50.00        Success
# 1      29.75        Success
# 3      65.00        Success
# 4     145.00        Success
# 5      64.68        Success
# ...      ...            ...
# 3855   59.00        Success
# 3971   63.23        Success
# 3993   63.23        Success
# 4000   63.23        Success
# 4020   63.23        Failure
#
# [964 rows x 7 columns]

# %%
launches_no_nulos
# Out:
#       Organization                                           Location  \
# 0           SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1             CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 3        Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4              ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# 5             CASC       LC-9, Taiyuan Satellite Launch Center, China
# ...            ...                                                ...
# 3855  US Air Force            SLC-4W, Vandenberg AFB, California, USA
# 3971  US Air Force           SLC-20, Cape Canaveral AFS, Florida, USA
# 3993  US Air Force           SLC-20, Cape Canaveral AFS, Florida, USA
# 4000  US Air Force           SLC-20, Cape Canaveral AFS, Florida, USA
# 4020  US Air Force           SLC-20, Cape Canaveral AFS, Florida, USA
#
#                             Date  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 3     Thu Jul 30, 2020 21:25 UTC
# 4     Thu Jul 30, 2020 11:50 UTC
# 5     Sat Jul 25, 2020 03:13 UTC
# ...                          ...
# 3855  Fri Jul 29, 1966 18:43 UTC
# 3971  Thu May 06, 1965 15:00 UTC
# 3993  Thu Feb 11, 1965 15:19 UTC
# 4000  Thu Dec 10, 1964 16:52 UTC
# 4020  Tue Sep 01, 1964 15:00 UTC
#
#                                                  Detail  Rocket_Status  \
# 0          Falcon 9 Block 5 | Starlink V1 L9 & BlackSky   StatusActive
# 1                   Long March 2D | Gaofen-9 04 & Q-SAT   StatusActive
# 3          Proton-M/Briz-M | Ekspress-80 & Ekspress-103   StatusActive
# 4                            Atlas V 541 | Perseverance   StatusActive
# 5     Long March 4B | Ziyuan-3 03, Apocalypse-10 & N...   StatusActive
# ...                                                 ...            ...
# 3855                                  Titan IIIB | KH-8  StatusRetired
# 3971                         Titan IIIA | LES 2 & LCS 1  StatusRetired
# 3993                                 Titan IIIA | LES 1  StatusRetired
# 4000                           Titan IIIA | Transtage 2  StatusRetired
# 4020                           Titan IIIA | Transtage 1  StatusRetired
#
#        Price Mission_Status
# 0      50.00        Success
# 1      29.75        Success
# 3      65.00        Success
# 4     145.00        Success
# 5      64.68        Success
# ...      ...            ...
# 3855   59.00        Success
# 3971   63.23        Success
# 3993   63.23        Success
# 4000   63.23        Success
# 4020   63.23        Failure
#
# [964 rows x 7 columns]

# %% [markdown]
# ## Agrupar por fecha

# %%
# Convertir la columna 'Date' a formato datetime si no está en ese formato
launches_no_nulos['Date'] = pd.to_datetime(launches_no_nulos['Date'], errors='coerce')

# Filtrar las fechas del año 2000
launches_no_nulos_2000 = launches_no_nulos[launches_no_nulos['Date'].dt.year == 2000]

# Mostrar el DataFrame filtrado
launches_no_nulos_2000
# Out:
# C:\Users\Sernita\AppData\Local\Temp\ipykernel_3160\2191281624.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   launches_no_nulos['Date'] = pd.to_datetime(launches_no_nulos['Date'], errors='coerce')
#      Organization                                           Location  \
# 1158         CASC       LC-2, Xichang Satellite Launch Center, China
# 1162         NASA         LC-39B, Kennedy Space Center, Florida, USA
# 1168         CASC       LC-2, Xichang Satellite Launch Center, China
# 1172         NASA         LC-39A, Kennedy Space Center, Florida, USA
# 1173     Northrop  Stargazer, Ronald Reagan Ballistic Missile Def...
# 1175    Kosmotras       Site 109/95, Baikonur Cosmodrome, Kazakhstan
# 1177     Lockheed            SLC-4W, Vandenberg AFB, California, USA
# 1179         NASA         LC-39B, Kennedy Space Center, Florida, USA
# 1185     Northrop             SLC-8, Vandenberg AFB, California, USA
# 1192     Northrop         Stargazer, Vandenberg AFB, California, USA
# 1194         NASA         LC-39A, Kennedy Space Center, Florida, USA
# 1195     Eurockot            Site 133/3, Plesetsk Cosmodrome, Russia
# 1203     Northrop          SLC-576E, Vandenberg AFB, California, USA
# 1206         NASA         LC-39A, Kennedy Space Center, Florida, USA
# 1210     Northrop             SLC-8, Vandenberg AFB, California, USA
# 1211         CASC       LC-2, Xichang Satellite Launch Center, China
#
#                           Date  \
# 1158 2000-12-20 16:20:00+00:00
# 1162 2000-11-30 03:06:00+00:00
# 1168 2000-10-30 16:02:00+00:00
# 1172 2000-10-11 23:17:00+00:00
# 1173 2000-10-09 05:38:00+00:00
# 1175 2000-09-26 10:05:00+00:00
# 1177 2000-09-21 10:22:00+00:00
# 1179 2000-09-08 12:45:00+00:00
# 1185 2000-07-19 20:09:00+00:00
# 1192 2000-06-07 13:19:00+00:00
# 1194 2000-05-19 10:11:00+00:00
# 1195 2000-05-16 08:27:00+00:00
# 1203 2000-03-12 09:29:00+00:00
# 1206 2000-02-11 16:43:00+00:00
# 1210 2000-01-27 03:03:00+00:00
# 1211 2000-01-25 16:45:00+00:00
#
#                                                  Detail  Rocket_Status  Price  \
# 1158                          Long March 3A | Beidou-1B   StatusActive   69.7
# 1162                   Space Shuttle Endeavour | STS-97  StatusRetired  450.0
# 1168                          Long March 3A | Beidou-1A   StatusActive   69.7
# 1172                   Space Shuttle Discovery | STS-92  StatusRetired  450.0
# 1173                                   Pegasus | HETE 2  StatusRetired   40.0
# 1175                          Dnepr | Megsat 1 & Others  StatusRetired   29.0
# 1177                            Titan II(23)G | NOAA-16  StatusRetired   35.0
# 1179                   Space Shuttle Atlantis | STS-106  StatusRetired  450.0
# 1185                         Minotaur I | MightySat 2.1   StatusActive   40.0
# 1192                                 Pegasus XL | TSX-5   StatusActive   40.0
# 1194                   Space Shuttle Atlantis | STS-101  StatusRetired  450.0
# 1195             Rokot/Briz KM | SimSat 1 & 2 (Iridium)  StatusRetired   41.8
# 1203  Minotaur C (Taurus) | Multispectral Thermal Im...   StatusActive   45.0
# 1206                   Space Shuttle Endeavour | STS-99  StatusRetired  450.0
# 1210                                Minotaur I | JAWSat   StatusActive   40.0
# 1211                        Long March 3A | ChinaSat-22   StatusActive   69.7
#
#      Mission_Status
# 1158        Success
# 1162        Success
# 1168        Success
# 1172        Success
# 1173        Success
# 1175        Success
# 1177        Success
# 1179        Success
# 1185        Success
# 1192        Success
# 1194        Success
# 1195        Success
# 1203        Success
# 1206        Success
# 1210        Success
# 1211        Success

# %% [markdown]
# ### Organización de misiones espaciales
#
# - **¿Cuántos lanzamientos se realizaron por año?**

# %%
# Agrupar por título y calcular el promedio y la mediana del salario para cada título
df_grouped = launches_no_nulos_2000.groupby('Organization')['Date'].agg(['count']).reset_index()

# Renombrar las columnas para mayor claridad
df_grouped.columns = ['Organization',  'Organization_count']

# Mostrar el DataFrame resultante
df_grouped
# Out:
#   Organization  Organization_count
# 0         CASC                   3
# 1     Eurockot                   1
# 2    Kosmotras                   1
# 3     Lockheed                   1
# 4         NASA                   5
# 5     Northrop                   5

# %%
# Ordenar el DataFrame por la columna 'Organization_count' de manera descendente
df_grouped_sorted = df_grouped.sort_values(by='Organization_count', ascending=False)

# Mostrar el DataFrame ordenado
print("Títulos ordenados de mayor a menor por número de lanzamientos:")
print(df_grouped_sorted)
# Out:
# Títulos ordenados de mayor a menor por número de lanzamientos:
#   Organization  Organization_count
# 4         NASA                   5
# 5     Northrop                   5
# 0         CASC                   3
# 1     Eurockot                   1
# 2    Kosmotras                   1
# 3     Lockheed                   1

# %%
# Obtener el título con el mayor número de lanzamientos
titulo_max_lanzamientos = df_grouped.loc[df_grouped['Organization_count'].idxmax(), 'Organization']

print("Título con el mayor número de lanzamientos:", titulo_max_lanzamientos)
# Out:
# Título con el mayor número de lanzamientos: NASA
